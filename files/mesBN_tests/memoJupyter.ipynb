# %% [markdown]
# # Mémo concernant Jupyter NoteBook :
#
# ![JupyterNoteBook.png](attachment:JupyterNoteBook.png)
#
#
# - Le site : https://jupyter.org/
#
#
# - La documentation : https://jupyter-notebook.readthedocs.io
#
# - Pour tester : https://jupyter.org/try
#
#
# - https://nbviewer.jupyter.org/ permet de visualiser en l'état (non interactif) tous les Notebooks du web...
# > Comme par exemple : https://nbviewer.jupyter.org/github/ericECmorlaix/mesBN/blob/master/index.ipynb
# >
# > Le bouton <button class='fa fa-download icon-download btn btn-xs btn-default'></button> permet alors de télécharger une copie du fichier en local.
# >
# > Il existe des extensions de navigateur pour ouvrir en un clic (ou en deux...) un notebook via nbviewer, par exemple :
# > - pour [Chrome](https://chrome.google.com/webstore/detail/open-in-nbviewer/ihlhlehlibooakiicbiakgojckpnlali) ou [notebook-buddy](https://chrome.google.com/webstore/search/jupyter%20nbviewer)
# > - pour [Firefox](https://addons.mozilla.org/en-US/firefox/addon/notebook-buddy/)
# > - pour [autres](https://github.com/jiffyclub/open-in-nbviewer)
#
# - https://kyso.io/ permet d'obtenir un affichage sélectif (avec ou sans cellules de code, avec ou sans sorties) voir l'[article](https://towardsdatascience.com/a-new-way-to-share-collaborate-on-jupyter-notebooks-483f8f0c46ef)

# %% [markdown]
# ## Pour disposer d'un environnement interactif Jupyter :
#
# ### Local sur iPad, iPhone :
# - l'application Carnets : https://apps.apple.com/us/app/carnets/id1450994949
# > [Notice de Yann GUELOU pour récupérer un Notebook sur iPad](http://sme.lycee.ecmorlaix.fr/YG/2019/Python-BN/tuto.html)
#
# ### Local sur PC :
# - La solution la plus pratique est d'installer une distribution Anaconda : https://www.anaconda.com/distribution/
#
# ### En ligne :
#
# > cf article avec compartif :  https://www.dataschool.io/cloud-services-for-jupyter-notebook/
#
# - Chez Microsoft Azure Notebooks : https://notebooks.azure.com/
#     > *Le travail de Tony HIRST permet d'explorer : https://notebooks.azure.com/OUsefulInfo/projects/gettingstarted*
#
# - Chez Google Colaboratory : https://colab.research.google.com
#     > *Google a participé à l'origine de la création du projet Jupyter puis a poursuivi son développement indépendemment pour des besoins internes avant que de le rendre public en l'ajoutant à sa suite d'outils bureautique. C'est différent mais compatible et permet le partage...*
#
# - Pour ouvrir de façon interactive mais temporaire un dépot GitHub ou GitLab dans un environnement Jupyter : https://mybinder.org/.
#     > ***Attention**, il faut ajouter un [fichier de configuration](https://mybinder.readthedocs.io/en/latest/using.html#preparing-a-repository-for-binder) soit en [pip](https://github.com/binder-examples/requirements) soit en [conda](https://github.com/binder-examples/conda) pour indiquer à la machine virtuelle les paquets (Noyaux, Modules, Extensions) à installer.*
#
# - Pour installer son propre serveur JupyterHub :
#     - le plus simple, suivre la documentation : https://tljh.jupyter.org/en/latest/
# > *[nbgitpuller]() pour distribuer des fichiers supports de cours aux élèves.*
#
#     - autres solutions :
#         - https://jupyterhub.readthedocs.io
#         - https://z2jh.jupyter.org
#         - https://pythonforundergradengineers.com/installing-jupyter-hub.html
#         -
#
#
# ## Extensions et/ou Noyaux complémentaires :
# >*Certaines distributions viennent avec des noyaux (Kernels) et des extensions déjà intégrées.*
#
# - Diaporama RISE : https://github.com/damianavila/RISE
#     > [Tutoriel de Microsoft Azure Notebooks pour RISE](https://docs.microsoft.com/fr-fr/azure/notebooks/present-jupyter-notebooks-slideshow)
#
# - [nbconvert](https://nbconvert.readthedocs.io) pour convertir les Notebook du format `.ipynb` vers `.pdf`, `.tex`,...
#
# - [metakernel](https://github.com/Calysto/metakernel) pour inclure des codes Blockly, Processing, et bien plus encore...: [documentation](http://calysto.github.io/metakernel/), [exemples](http://nbviewer.jupyter.org/github/Calysto/metakernel/tree/master/examples/) : [Python Tutor](https://jupyter.brynmawr.edu/services/public/dblank/Examples/Tutor%20Magic%20in%20IPython.ipynb), ...
#
# - [nbtutor](https://github.com/lgpage/nbtutor) pour visualiser l'exécution d'un code Python ligne par ligne dans un notebook tel qu'avec [Python Tutor](https://github.com/lgpage/nbtutor), lire [l'article de Tony Hirst](https://blog.ouseful.info/2017/01/27/python-code-stepper-debugger-tutor-for-jupyter-notebooks-nbtutor/) à ce sujet.
#
# - [nbautoeval](https://github.com/parmentelat/nbautoeval) une solution pour créer des exercices d'autoévaluation en python dans un Jupyter notebook.
#
# - [Jupyter-PHP](https://litipk.github.io/Jupyter-PHP-Installer/) un noyau pour php.
#
# - la collection [Unofficial Jupyter Notebook Extensions](https://github.com/ipython-contrib/jupyter_contrib_nbextensions) qui intègre notamment :
#     - le gestionnaire d'extensions [jupyter_nbextensions_configurator](https://github.com/Jupyter-contrib/jupyter_nbextensions_configurator) ;
#     - [Variable Inspector](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/nbextensions/varInspector/README.html) pour afficher l'état des variables dans une fenêtre flottante ;
#     - [gist-it](https://medium.com/deena-does-data-science/jupyter-notebook-extensions-e6b57d004e8e) pour publier un jupyter notebook sur GitHub en un clic.
#     Pour Installer ces extensions
# taper à la suite en lignes de command
# > !conda install -c conda-forge jupyter_nbextensions_configurator
#
# OU
#
# > pip install jupyter_contrib_nbextensions
#
# PUIS
#
# > jupyter contrib nbextension install --user
#
# ET
#
# > jupyter nbextension enable varInspector/main
#
#
# > *Ces extensions ne fonctionnent pas dans JupyterLab*
#
# ## Jupyterlab :
# > L'environnement Jupyter du futur !
# >
# > Pour basculer de l'environnement Jupyter NoteBook classique à l'environnement Lab, il suffit de remplacer dans l'URL le `tree` par un `lab` et inversement...
# >
# >C ’est une nouvelle génération de l’interface web utilisateur, plus évoluée, qui intègre les applications de Notebook et de Terminal classiques et adjoint une console Ipython et de nouvelles fonctionnalités graphiques pour la gestion des fichiers de l’espace personnel et l’affichage interactif simultané sur de multiples fenêtres.
# >
# > De plus, cet environnement autorise l’intégration d’applications en extensions comme un éditeur de diagrammes ou encore un éditeur/compilateur LaTeX…
#
#
# - https://www.stat4decision.com/fr/jupyterlab-python/
# - https://towardsdatascience.com/jupyter-lab-evolution-of-the-jupyter-notebook-5297cacde6b
# - https://blog.jupyter.org/a-diagram-editor-for-jupyterlab-a254121ff919
#
#
# - https://jupyterlab.readthedocs.io/en/stable/
#
#
# - https://github.com/jupyterlab/jupyterlab-latex
# - https://github.com/jupyterlab/jupyterlab-github
# - https://github.com/QuantStack/jupyterlab-drawio
#
# ## Trucs & astuces :
#
# - pour ne télécharger qu'un seul fichier d'un dépot GitHub (ou GitLab) le visualiser dans [nbviewer](https://nbviewer.jupyter.org/) puis cliquer sur le bouton <button class='fa fa-download icon-download btn btn-xs btn-default'></button>
#
# - Une liste assez exhaustive de solutions : [awesome-jupyter](https://awesomeopensource.com/project/markusschanta/awesome-jupyter)
#
# - [28 Conseils, astuces et raccourcis](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)
#
#
# ## Ressources : articles, dépots, livres, tutoriels, ... :
#
# - Un tutoriel pour débuter : https://realpython.com/jupyter-notebook-introduction/
#
# - https://www.ionos.fr/digitalguide/sites-internet/developpement-web/jupyter-notebook/
# - https://www.lemondeinformatique.fr/actualites/lire-jupyter-notebook-apporte-une-vue-360-des-donnees-aux-developpeurs-75077.html
# - https://www.stat4decision.com/fr/jupyterlab-python/
# - https://connect.ed-diamond.com/Linux-Pratique/LP-092/Jupyter-le-couteau-suisse-des-interpretateurs-interactifs
#
# ### Livres :
#
# - Bob CORDEAU, Laurent POINTAL : [Python 3 - Apprendre à programmer avec PyZo et Jupyter Notebook](https://www.dunod.com/sciences-techniques/python-3)
# - Dan Toomey : [Learning Jupyter 5](https://www.amazon.fr/Learning-Jupyter-interactive-JavaScript-JupyterLab/dp/1789137403/ref=dp_ob_title_bk)
#
#
# ### Exemples :
#
# - https://github.com/jupyter/jupyter/wiki/A-gallery-of-interesting-Jupyter-Notebooks
#
# - https://nbviewer.jupyter.org/github/ipython/ipython/tree/2.x/examples/
#
# - Jake Vanderplas : https://github.com/jakevdp
#
# #### Education :
#
# - Une référence pédagogique gratuite en ligne : [Teaching and Learning with Jupyter](https://jupyter4edu.github.io/jupyter-edu-book/index.html), et son dépot [GitHub](https://github.com/jupyter4edu/jupyter-edu-book)
#
# - Tony HIRST :  https://github.com/psychemedia/showntell/
# - Luca De Feo : https://github.com/defeo
#
#
# - Fabrice DUMONT : https://gitlab.com/lecoinduprogrammeur/jupyter-notebooks
# - Gérard VIDAL, Eric LE JAN : https://github.com/g-vidal/CahierDeProgrammes/
# - Jean Claude MEILLAND : https://github.com/debimax/cours-debimax
# - https://github.com/matchre
# - Yann GUELOU : https://github.com/GUELOU
# - Yannig SALAUN : https://github.com/ysalaun1
# - Fréderic MANDON : http://www.maths-info-lycee.fr/index.html
# - Olivier LECLUSE : https://lecluseo.scenari-community.org/co/Initiation_Python.html
# - Christophe CASSEAU : http://isncaju.wixsite.com/isncaju/python
# - Stephan VAN ZUIJLEN : https://github.com/vanzuijlen/SNT
# - Eric MADEC : https://github.com/ericECmorlaix/mesBN
# -
#
#  #### Systèmes :
#
# - Poppy Ergo Jr : https://www.poppy-education.org/activites/tuto-python-robot-ergojr/
# - RedPitaya STEMlab : https://github.com/RedPitaya/jupyter/blob/ec3ebaa41000006b0b18e963661858bbf4989903/welcome.ipynb
# - RaspberryPi GPIO : https://www.hackster.io/mjrobot/rpi-physical-computing-using-jupyter-notebook-056fa8
# - Adafruit CircuitPython CPX : https://learn.adafruit.com/circuitpython-with-jupyter-notebooks/
# - BBC micro:bit : https://github.com/takluyver/ubit_kernel
# - ESP8266 et ESP32 :
#     - dépot https://github.com/goatchurchprime/jupyter_micropython_kernel/
#     - tutoriel https://towardsdatascience.com/micropython-on-esp-using-jupyter-6f366ff5ed9
# - Lego EV3 : https://github.com/sshopov/pyconau2017/blob/master/final.ipynb
#
#
# #### Modules, Kernels :
#
# - SQL : https://github.com/royalosyin/Practice-SQL-with-SQLite-and-Jupyter-Notebook
# - folium : https://github.com/python-visualization/folium
# - VPython : https://github.com/BruceSherwood/vpython-jupyter
# - ipywidgets :
#     - https://linuxfr.org/news/creer-une-application-web-avec-jupyter-ipywidgets-et-voila-7b03d5dd-ab10-47cb-a2bd-bd99fa9e2457
#     - https://makina-corpus.com/blog/metier/2019/augmenter-linteractivite-de-vos-notebooks-jupyter-1
#     - https://ipywidgets.readthedocs.io/en/stable/index.html
#     - https://jupyter.org/widgets.html

# %% [markdown]
# A classer :
#     - https://towardsdatascience.com/advanced-jupyter-notebooks-a-tutorial-3569d8153057
#     - https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
#     - https://github.com/mauhai/awesome-jupyterlab
#     - https://towardsdatascience.com/jupyter-notebook-for-beginners-a-tutorial-f55b57c23ada
#     - https://towardsdatascience.com/why-python-is-not-the-programming-language-of-the-future-30ddc5339b66

# %% [markdown]
# - Une note CodiMD : https://carnets.binets.fr/s/SyZy8ZYdf
#
#
# #### Vidéo :
#
# - introduction en Anglais : https://youtu.be/HW29067qVWk
